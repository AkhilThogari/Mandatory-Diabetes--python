# %% [markdown]
# # **INTRODUCTION**

# %% [markdown]
# Mandaroty dataset diabetes. This dataset comes from the National Institute of Diabetes and Digestive and Kidney Diseases. The objective of the dataset is to  predict the diagnosis of whether  a patient has diabetes, based on certain diagnostic measures contained in the dataset.

# %% [markdown]
# **Variables used in the dataset**

# %% [markdown]
# * Pregnancies: Number of times pregnant
#
# * Glucose: Plasma glucose concentration 2 hours in an oral glucose tolerance test
#
# * Blood Pressure: Diastolic blood pressure (mm Hg)
#
# * Skin Thickness: Triceps skin fold thickness (mm)
#
# * Insulin: 2-Hour serum insulin (mu U/ml)
#
# * BMI: Body mass index (weight in kg/(height in m)^2)
#
# * Diabetes Pedigree Function: Diabetes pedigree function
#
# * Age: Age (years)
#
# * Outcome: Class variable (0 or 1) 0 mean non-diabetic and 1 means diabetic

# %% [markdown]
# ### **1.Please do the basic exploration of data and explain all datatypes (nominal, ordinal, discrete or continuous).**

# %% [markdown]
# When we check the dataset ,
# * **Pranancies**,Pranancies comes under the Discrete level data because Pregnancies means no  of times pregnant it will counted not measured.
#
# * **Glucose** , Glucose is mesured in mmol/L means millimoles per litre so as it comes under Continuous level data.
#
# * **Blood Pressure**,Blood pressure can be measured to as many decimals as the measuring instrument allows so, it comes under Continuous level data.
#
# * **SkinThickness**, SkinThickness can be measured and intermediate valuse can possible so it is Continuous data.
#
# * **Insulin**, Insulin is can be countable data so it comes under Discrate level data.
#
# * **BMI**, BMI means Body Mass Index it is measurable data so it comes under Continuous data
#
# * **DiabetesPedigreeFunction**,DiabetesPedigreeFunction comes under Continuous data.
# * **Age**, Age is a ordinal level value because , order is important but not the magnitude.
# * **Outcome**,Outcome data will come under Nominal level data because it don't anu oder and magnitude , basically 0 mean non-diabetic ,1 means diabetic

# %% [markdown]
# ### Dataset Explanation

# %% [markdown]
# Allmost all columns names are self explanatory however,there are 2 coloumns to explain BMI and outcome columns
#
# * Pregnancies Number of times a woman became pregnant
#
# * BMI means Body Mass Divided by the square of  body height and  expressed in units of kg/m², as a result of mass in kilograms and height in meters.
#
# * Diabetes Pedigree Function:Diabetes pedigree a function which scores likelihood of diabetes based on family history ,Age Outcome: Class variable (0 if non-diabetic, 1 if diabetic)
#
# * Outcome column basically used to identify weather a persion is diabete or not , if the value is 0 means non-diabetic , 1 means diabetic

# %% [markdown]
# ## **Importing the Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from scipy.stats import skew

# %% [markdown]
# ## **Reading the Dataset**

# %%
#reading the dataset
df = pd.read_csv("mandatory_diabetes.csv")

# %%
#lest check how data lookes like 
#lets take first 5 rows as sample
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#displaying the last five rows
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
#lets check the infoermation of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# every coloumn is saved with perfect data formated no need to change the data formate of data.

# %%
#Lets check for null values
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#check for duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
#lests check the Summery of the dataset
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# **observation:**
# * We note that minimum value for columns such as Glucose,BloodPressure,Insulin,BMI,SkinThickness are 0 which is not possible , hence these must be missing values which are encoded as 0 We can use imputation techniques to deal with these

# %% [markdown]
# # Data Cleaning and Data Formating

# %% [markdown]
# ### **11.If there are missing values, please try to fill those missing values and give appropriate reasons.**

# %%
#Lets conver 0 values in Glucose,BloodPressure,Insulin,BMI,SkinThickness to Null so future we can conver them easly
corrupted_data=df.loc[:,'Glucose':'BMI'] #Extracting the coloums Glucose,BloodPressure,Insulin,BMI
corrupted_data.replace(0,np.nan,inplace=True) #where ever 0 in coloum it replaced with null value 
df.loc[:,'Glucose':'BMI']=corrupted_data #saving the changes into orginal dataset

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0      NaN  33.6
# 1            1     85.0           66.0           29.0      NaN  26.6
# 2            8    183.0           64.0            NaN      NaN  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#lets check null value 
df.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %% [markdown]
# There are lot of null values present overall. Insulin have count of null values 374 and Glucose have low count 5 for rest value can identify by above table.

# %% [markdown]
# **lets check skewness of the data for all columns, specially Glucose,SkinThickness,BloodPressure,Insulin,BMI to change the null value in those columns**

# %%
hplot = df.hist(figsize = (20,20))

# %%
df2 = df.copy()

# %% [markdown]
# **Observation**
# * By looking above fig's there found skewness.
# * **Glucose** graph is symantic , no skewness.
# * **BloodPressure** graph is symantic , no skewness.
# * **Insuline** graph have right skewness.
# * **BMI** graph have right skewness.
# * **SkinThickness** graph have right skewness

# %% [markdown]
# As per Concept,
# * if there is no skewness Mean is best for replacing the null values
# * if there is skewness Median is best for replacing the null values
#
# as per above concept.
#
# * Glucose , BloodPressure null values will replace with Mean
# * Insuline, BMI ,SkinThickness null values will replace with Median

# %%
#Replacing the Null values by using the above rules
df2['Glucose'].fillna(df2['Glucose'].mean(), inplace = True) 
df2['BloodPressure'].fillna(df2['BloodPressure'].mean(), inplace = True)
df2['SkinThickness'].fillna(df2['SkinThickness'].median(), inplace = True)
df2['Insulin'].fillna(df2['Insulin'].median(), inplace = True)
df2['BMI'].fillna(df2['BMI'].median(), inplace = True)

# %%
#lest check if there is any null values present 
df2.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# From the above table , there are no null value present now.

# %%
# check for first 10 values of the dataset 
df2.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0      72.000000           35.0    125.0  33.6
# 1            1     85.0      66.000000           29.0    125.0  26.6
# 2            8    183.0      64.000000           29.0    125.0  23.3
# 3            1     89.0      66.000000           23.0     94.0  28.1
# 4            0    137.0      40.000000           35.0    168.0  43.1
# 5            5    116.0      74.000000           29.0    125.0  25.6
# 6            3     78.0      50.000000           32.0     88.0  31.0
# 7           10    115.0      72.405184           29.0    125.0  35.3
# 8            2    197.0      70.000000           45.0    543.0  30.5
# 9            8    125.0      96.000000           29.0    125.0  32.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %% [markdown]
# **This is the Result after cleaning and removing the null values**

# %%
#lets check if there is any chacnge in skewness
hplot2 = df2.hist(figsize = (20,20))

# %% [markdown]
# Q11 ENDED

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %% [markdown]
# ### **2.Calculate appropriate measures of central tendency for Glucose and outcome column variable only? Do not give all results.**

# %% [markdown]
# *Calculating Central tendency for Glucode*

# %%
Gmean  = df2['Glucose'].mean()
Gmedian=df2['Glucose'].median()
Gmode=list(df2['Glucose'].mode())
print(f"Mean: {Gmean}")
print(f"Median: {Gmedian}")
print(f"Mode: {Gmode}")
# Out:
# Mean: 121.68676277850587
# Median: 117.0
# Mode: [99.0, 100.0]

# %% [markdown]
# *Calculating Central tendency for Outcome*

# %%
Omean  = df2['Outcome'].mean()
Omedian=df2['Outcome'].median()
Omode=list(df2['Outcome'].mode())
print(f"Mean: {Omean}")
print(f"Median: {Omedian}")
print(f"Mode: {Omode}")
# Out:
# Mean: 0.3489583333333333
# Median: 0.0
# Mode: [0]

# %% [markdown]
# ### **3.Please provide 5 points data summaries for required columns?**

# %%
#Data summery
df2.loc[:,'Pregnancies':'SkinThickness'].boxplot(figsize = (10,10))

# %%
df2.loc[:,'Insulin':'DiabetesPedigreeFunction'].boxplot(figsize = (10,10))

# %% [markdown]
# ### **4.Please create an appropriate plot to see the distribution of Outcome variable?**

# %%
plot1 = df2.Outcome.value_counts().plot(kind='bar')
plot1.set_xticklabels(["Non-Diabetic","Diabets"])
plt.title("distribution of Outcome variable")
plt.ylabel("Total count")
df2.Outcome.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# **Observation:**
#  From the above plot when we compire Diabets with non-diabetics , non-diabetics count is more

# %% [markdown]
# ### **5.Is there a difference in glucose level between diabetic and non-diabetic? Similarly for insulin and diabetic vs nondiabetic.**

# %%
plot2 = sns.barplot(x = df2['Outcome'], y = df2.groupby(['Outcome'])['Glucose'].count())
plot2.set_xticklabels(["Non-Diabetic","Diabets"])
# Out:
# [Text(0, 0, 'Non-Diabetic'), Text(0, 0, 'Diabets')]

# %%
plot3 = sns.barplot(x = 'Outcome', y = df2.groupby(['Outcome'])['Insulin'].mean(), data = df2 )
plot3.set_xticklabels(["Non-Diabetic","Diabets"])
# Out:
# [Text(0, 0, 'Non-Diabetic'), Text(0, 0, 'Diabets')]

# %% [markdown]
# **Observation:**
# * When we check the levels of Glucose and insulin from above fig's ,Diabets people have more glucose level and Non-Diabetic people have more insulin level.

# %% [markdown]
# ### **6.Please examine the relationship between insulin and glucose level using appropriate plot.**

# %%
plot4 = sns.scatterplot(x=df['Glucose'],y=df['Insulin'])
diabetic = mpatches.Patch(color='blue', label='Diabetic')
non = mpatches.Patch(color='orange', label='Non-Diabetic')
plt.legend(handles=[non,diabetic])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2fc8952776a4> in <module>()
# ----> 1 plot4 = sns.scatterplot(x=df['Glucose'],y=df['Insulin'])
#       2 diabetic = mpatches.Patch(color='blue', label='Diabetic')
#       3 non = mpatches.Patch(color='orange', label='Non-Diabetic')
#       4 plt.legend(handles=[non,diabetic])
#
# NameError: name 'sns' is not defined

# %% [markdown]
# **Observation:**
# As per the above scatter plot there is Positive correlation between Glucose and Insulin values.

# %% [markdown]
# ### **7.Please examine the distribution of numerical data and explain which variables normally distributed and which variables are seem to be skewed. Please also tell the direction of skewness.**

# %%
data3 = df2.loc[:,'Pregnancies':'DiabetesPedigreeFunction'].hist(figsize = (15,15))
plt.kde = True

# %%
#Blood Pressure
Bmean  = df2['BloodPressure'].mean()
Bmedian=df2['BloodPressure'].median()
Bmode=list(df2['BloodPressure'].mode())
print(f"Mean: {Bmean}")
print(f"Median: {Bmedian}")
print(f"Mode: {Bmode}")
# Out:
# Mean: 72.40518417462486
# Median: 72.20259208731241
# Mode: [70.0]

# %%
#Glucose it already calculated in  Q2 , using those values
print(f"Mean: {Gmean}")
print(f"Median: {Gmedian}")
print(f"Mode: {Gmode}")
# Out:
# Mean: 121.68676277850587
# Median: 117.0
# Mode: [99.0, 100.0]

# %%
#SkinThickness
Smean  = df2['SkinThickness'].mean()
Smedian=df2['SkinThickness'].median()
Smode=list(df2['SkinThickness'].mode())
print(f"Mean: {Smean}")
print(f"Median: {Smedian}")
print(f"Mode: {Smode}")
# Out:
# Mean: 29.108072916666668
# Median: 29.0
# Mode: [29.0]

# %%
#BMI
BMmean  = df2['BMI'].mean()
BMmedian=df2['BMI'].median()
BMmode=list(df2['BMI'].mode())
print(f"Mean: {BMmean}")
print(f"Median: {BMmedian}")
print(f"Mode: {BMmode}")
# Out:
# Mean: 32.4552083333333
# Median: 32.3
# Mode: [32.3]

# %% [markdown]
# **Observation:**
# * From the Above graphs excluded the Outcome table because it is Qualitative Data.
#
# * Glucose and Blood Pressure,SkinThickness,BMI it have no skewness and it is symmetrical Distribution.
# * BMI have median is equal to mode and mean is not equal as desimal is not equal.
# * Pragancies, Insulin , Diabetes Pedgree Function those are Right Skewness
# * However, no value is fall numder Normal Distibution, to be a normal distubution , the curve should be fall under Perfectly Symmetrical Distribution and mean , median , mode values should be same, no above columns have same mean , median mode values.

# %%
df2.head(1)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    125.0  33.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1

# %% [markdown]
# ### **8.Please calculate the skewness value and divide variables into symmetrical, moderately skewed and highly skewed.**

# %%
#Calculation the Skewness for df columns ,skeness formula is 3 * (Mean – Median) / Standard Deviation
def skewee_data(df):
  l ={}
  for i in df:
    if i == "Outcome" or i == "Age": #if the dataset countered outcome , age then it will not considered
      continue
    else:
      stds = 3 * (df[i].mean()-df[i].median()) /df[i].std() #calculating the skwness value
      l[i]=stds
  return l

# %%
#Fairly Symmetrical means value should be b/w -0.5 to 0.5
#Moderate Skewed means value should be b/w 	-0.5 to -1.0 and 0.5 to 1.0
#Highly Skewed means value should be b/w 	< -1.0 and > 1.0
skew = skewee_data(df2)
for i in skew:
  if(skew[i]>-1 and skew[i]<-0.5 or skew[i]>0.5 and skew[i]<1):
    print(f"{i} and value {skew[i]} --- Moderately Skewed")
  elif(skew[i]<-1 or skew[i]>1):
    print(f"{i} and value {skew[i]} ----- High Skewed")
  elif(skew[i]>-0.5 and skew[i]<0.5):
    print(f"{i} and value {skew[i]} --- is Symmetrical")
# Out:
# Pregnancies and value 0.752366083476181 --- Moderately Skewed
# Glucose and value 0.4619632000586797 --- is Symmetrical
# BloodPressure and value 0.05024461541447675 --- is Symmetrical
# SkinThickness and value 0.036879831498771096 --- is Symmetrical
# Insulin and value 0.5442690403302695 --- Moderately Skewed
# BMI and value 0.06772553089476514 --- is Symmetrical
# DiabetesPedigreeFunction and value 0.8997982991431914 --- Moderately Skewed

# %% [markdown]
# **Observation:**
# * The Pregnancies,Diabetes Pedigree Function Insulin are Highly Skewed.
# * Glucose,BloodPressure,SkinThickness,BMI is Symmetrical , it is nor prefectly Symmetrical but it is Fairly Symmetrical.

# %% [markdown]
# ### **9.Please create appropriate plot to examine the outliers of these variables. Please name the variables which have outliers.**

# %%
data3 = df2.loc[:,'Pregnancies':'DiabetesPedigreeFunction'].boxplot(figsize = (15,15))

# %% [markdown]
# **Observation:**
# * For Preanacies, Blood Pressure , SkinThickness, Insulin, BMI, DiabetesPedigreeFunction have Outliers

# %%
df2.head(1)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    125.0  33.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1

# %% [markdown]
# ### **10.What should be the measures of central tendency and dispersion for skewed data?**

# %% [markdown]
# **From the Q8 we found the skewed values they are : Pregnancies ,Insulin , Diabetes.**

# %%
print(f"Pregnancies_Mean: {df2['Pregnancies'].mean()}")
print(f"Pregnancies_Median: {df2['Pregnancies'].median()}")
print(f"Pregnancies_Mode: {df2['Pregnancies'].median()}")
print(f"Pregnancies_Std: {df2['Pregnancies'].std()}")
print("----------------------------------------------------")
print(f"Insulin_Mean: {df2['Insulin'].mean()}")
print(f"Insulin_Median: {df2['Insulin'].median()}")
print(f"Insulin_Mode: {df2['Insulin'].median()}")
print(f"Pregnancies_Std: {df2['Insulin'].std()}")
print("----------------------------------------------------")
print(f"DiabetesPedigreeFunction_Mean: {df2['DiabetesPedigreeFunction'].mean()}")
print(f"DiabetesPedigreeFunction_Median: {df2['DiabetesPedigreeFunction'].median()}")
print(f"DiabetesPedigreeFunction_Mode: {df2['DiabetesPedigreeFunction'].median()}")
print(f"DiabetesPedigreeFunction_Std: {df2['DiabetesPedigreeFunction'].std()}")
print("----------------------------------------------------")
# Out:
# Pregnancies_Mean: 3.8450520833333335
# Pregnancies_Median: 3.0
# Pregnancies_Mode: 3.0
# Pregnancies_Std: 3.3695780626988623
# ----------------------------------------------------
# Insulin_Mean: 140.671875
# Insulin_Median: 125.0
# Insulin_Mode: 125.0
# Pregnancies_Std: 86.383059693181
# ----------------------------------------------------
# DiabetesPedigreeFunction_Mean: 0.4718763020833327
# DiabetesPedigreeFunction_Median: 0.3725
# DiabetesPedigreeFunction_Mode: 0.3725
# DiabetesPedigreeFunction_Std: 0.33132859501277484
# ----------------------------------------------------

# %% [markdown]
# Mean , Median , mode is centeral tendency and std data is  dispersion in skewed data.

# %% [markdown]
# ## **12.If skewness is present, try to perform transformation and explain the results.**

# %%
log_trans = np.log10(df2.loc[:,'BloodPressure':'DiabetesPedigreeFunction'])
log_trans.hist(figsize = (15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe0fe200510>,
# ...
#       dtype=object)

# %%
#transforming the pregnancies by using z-score , observed value - mean of sample devided by sandard deviation of the sample

df3 = df2['Pregnancies']
df3['Z-score_trans'] = (df2['Pregnancies']-df2['Pregnancies'].mean())/df2['Pregnancies'].std()

# %%
df3['Z-score_trans'].hist()

# %% [markdown]
# **Observation:**
# After Data Transformation almost all have became Fairly Symmetrical except Pregnancies.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# * Pragnecie rate is less in diabetic people while compired with non-diabetic people
# * Who ever are suffering from diabetic it seams that they have low blood pressure problems more.
# * Skin thickness is also increase in diabetic people.
# * Found that Glucose levels are more in diabetic people and insulin levels are less in non-diabetic people
